# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image
image = cv2.imread('eye1.webp')

# Plot the original image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original image')
plt.show()

# %%
# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Plot the grayscale image
plt.imshow(gray, cmap='gray')
plt.title('Grayscale image')
plt.show()

# %%
# Binarize the image using Otsu's thresholding
threshold, binarized  = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Plot the binarized image
plt.imshow(thresh, cmap='gray')
plt.title('Binarized image')
plt.show()

# %%
# Find edges in the image using Canny edge detection
edges = cv2.Canny(binarized, 100, 200)

# Plot the edge map
plt.imshow(edges, cmap='gray')
plt.title('Edge map')
plt.show()

# %%
# Perform Hough transform to detect circles
circles = cv2.HoughCircles(edges, cv2.HOUGH_GRADIENT, 1, 800, param1=100, param2=50, minRadius=0, maxRadius=0)

# %%
# Draw the circles on the image
if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
        cv2.circle(image, (x, y), r, (0, 255, 0), 4)

# %%
# Plot the image with the detected Pupil
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Detected Pupil')
plt.show()

# %%
# Read the FlowChart
FlowChart = cv2.imread('FC.png')

# %%
# FlowChart
plt.figure(figsize=(10, 10))
plt.imshow(FlowChart)
plt.title('Flow Chart')
# Out:
# Text(0.5, 1.0, 'Flow Chart')
